# %%
import requests
url = 'https://api.opendota.com/api/'

# %%
r = requests.get(url + 'proPlayers')
r
# Out:
# <Response [200]>

# %%
results = r.json()
results
# Out:
# [{'account_id': 88018,
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/4e/4e93fd4af7e0261db108e0f7e37593ae2eee0128.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/4e/4e93fd4af7e0261db108e0f7e37593ae2eee0128_full.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/4e/4e93fd4af7e0261db108e0f7e37593ae2eee0128_medium.jpg',
#   'cheese': 0,
#   'country_code': '',
#   'fantasy_role': 1,
#   'fh_unavailable': None,
#   'full_history_time': None,
#   'is_locked': False,
#   'is_pro': True,
#   'last_login': None,
#   'loccountrycode': None,
#   'locked_until': 0,
#   'name': 'GIFTIG!',
#   'personaname': 'zAHARASAURUS',
#   'profileurl': 'http://steamcommunity.com/profiles/76561197960353746/',
#   'steamid': '76561197960353746',
#   'team_id': 983699,
#   'team_name': 'Turtlemasters',
#   'team_tag': 'turtle'},
#  {'account_id': 88470,
# ...

# %%
payload = {'hero_id': 113}
r = requests.get(url + 'rankings', params=payload)

# %%
r
# Out:
# <Response [200]>

# %%
request2 = r.json()
request2
# Out:
# {'hero_id': 113,
#  'rankings': [{'account_id': '92734540',
#    'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/e1/e1404a3e5cf4c726372dbedef9feb3eae893d3a3.jpg',
#    'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/e1/e1404a3e5cf4c726372dbedef9feb3eae893d3a3_full.jpg',
#    'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/e1/e1404a3e5cf4c726372dbedef9feb3eae893d3a3_medium.jpg',
#    'cheese': 0,
#    'fh_unavailable': False,
#    'full_history_time': '2017-01-23T17:03:21.894Z',
#    'last_login': None,
#    'loccountrycode': None,
#    'personaname': 'Commend, Like, Subscribe',
#    'profileurl': 'http://steamcommunity.com/profiles/76561198053000268/',
#    'score': '10493757.707051847',
#    'solo_competitive_rank': '6415',
#    'steamid': '76561198053000268'},
#   {'account_id': '186223500',
# ...

# %%
r.url
# Out:
# 'https://api.opendota.com/api/proPlayers'
