# %%
# open file, create string
file = open('youth.txt', 'r')
raw_string = file.read()

# %%
import string

# %%
# Convert string to lowercase
new_string = raw_string.lower()

# %%
# Here's the new string
new_string
# Out:
# 'ï»¿youth\n\n_by_ isaac asimov\n\n\n    red and slim found the two strange little animals the morning after\n    they heard the thunder sounds. they knew that they could never show\n    their new pets to their parents.\n\n\n[illustration]\n\n\nthere was a spatter of pebbles against the window and the youngster\nstirred in his sleep. another, and he was awake.\n\nhe sat up stiffly in bed. seconds passed while he interpreted his\nstrange surroundings. he wasn\'t in his own home, of course. this was out\nin the country. it was colder than it should be and there was green at\nthe window.\n\n"slim!"\n\nthe call was a hoarse, urgent whisper, and the youngster bounded to the\nopen window.\n\nslim wasn\'t his real name, but the new friend he had met the day before\nhad needed only one look at his slight figure to say, "you\'re slim." he\nadded, "i\'m red."\n\nred wasn\'t his real name, either, but its appropriateness was obvious.\nthey were friends instantly with the quick unquestioning friendship of\nyoung ones not yet quite in adolescence, before even the first stains of\nadulthood began to make their appearance.\n\nslim cried, "hi, red!" and waved cheerfully, still blinking the sleep\nout of himself.\n\nred kept to his croaking whisper, "quiet! you want to wake somebody?"\n\nslim noticed all at once that the sun scarcely topped the low hills in\nthe east, that the shadows were long and soft, and that the grass was\nwet.\n\nslim said, more softly, "what\'s the matter?"\n\nred only waved for him to come out.\n\nslim dressed quickly, gladly confining his morning wash to the momentary\nsprinkle of a little lukewarm water. he let the air dry the exposed\nportions of his body as he ran out, while bare skin grew wet against the\ndewy grass.\n\nred said, "you\'ve got to be quiet. if mom wakes up or dad or your dad or\neven any of the hands then it\'ll be \'come on in or you\'ll catch your\ndeath of cold.\'"\n\nhe mimicked voice and tone faithfully, so that slim laughed and thought\nthat there had never been so funny a fellow as red.\n\nslim said, eagerly, "do you come out here every day like this, red? real\nearly? it\'s like the whole world is just yours, isn\'t it, red? no one\nelse around and all like that." he felt proud at being allowed entrance\ninto this private world.\n\nred stared at him sidelong. he said carelessly, "i\'ve been up for hours.\ndidn\'t you hear it last night?"\n\n"hear what?"\n\n"thunder."\n\n"was there a thunderstorm?" slim never slept through a thunderstorm.\n\n"i guess not. but there was thunder. i heard it, and then i went to the\nwindow and it wasn\'t raining. it was all stars and the sky was just\ngetting sort of almost gray. you know what i mean?"\n\nslim had never seen it so, but he nodded.\n\n"so i just thought i\'d go out," said red.\n\nthey walked along the grassy side of the concrete road that split the\npanorama right down the middle all the way down to where it vanished\namong the hills. it was so old that red\'s father couldn\'t tell red when\nit had been built. it didn\'t have a crack or a rough spot in it.\n\nred said, "can you keep a secret?"\n\n"sure, red. what kind of a secret?"\n\n"just a secret. maybe i\'ll tell you and maybe i won\'t. i don\'t know\nyet." red broke a long, supple stem from a fern they passed,\nmethodically stripped it of its leaflets and swung what was left\nwhip-fashion. for a moment, he was on a wild charger, which reared and\nchamped under his iron control. then he got tired, tossed the whip aside\nand stowed the charger away in a corner of his imagination for future\nuse.\n\nhe said, "there\'ll be a circus around."\n\nslim said, "that\'s no secret. i knew that. my dad told me even before we\ncame here--"\n\n"that\'s not the secret. fine secret! ever see a circus?"\n\n"oh, sure. you bet."\n\n"like it?"\n\n"say, there isn\'t anything i like better."\n\nred was watching out of the corner of his eyes again. "ever think you\nwould like to be with a circus? i mean, for good?"\n ...

# %%
# Make an empty string
cleaned_string = ''

# %%
for char in new_string:
#  add only the characters we want to our cleaned string
    if char in string.ascii_letters:
#         print(char)
        cleaned_string += char
    elif char in string.digits:
#         print(char)
        cleaned_string += char
    elif char in string.whitespace:
#         print(' ')
        cleaned_string += ' '

# cleaned_string

# %%
cleaned_string
# Out:
# 'youth    by  isaac  asimov              red  and  slim  found  the  two  strange  little  animals  the  morning  after          they  heard  the  thunder  sounds  they  knew  that  they  could  never  show          their  new  pets  to  their  parents      illustration      there  was  a  spatter  of  pebbles  against  the  window  and  the  youngster  stirred  in  his  sleep  another  and  he  was  awake    he  sat  up  stiffly  in  bed  seconds  passed  while  he  interpreted  his  strange  surroundings  he  wasnt  in  his  own  home  of  course  this  was  out  in  the  country  it  was  colder  than  it  should  be  and  there  was  green  at  the  window    slim    the  call  was  a  hoarse  urgent  whisper  and  the  youngster  bounded  to  the  open  window    slim  wasnt  his  real  name  but  the  new  friend  he  had  met  the  day  before  had  needed  only  one  look  at  his  slight  figure  to  say  youre  slim  he  added  im  red    red  wasnt  his  real  name  either  but  its  appropriateness  was  obvious  they  were  friends  instantly  with  the  quick  unquestioning  friendship  of  young  ones  not  yet  quite  in  adolescence  before  even  the  first  stains  of  adulthood  began  to  make  their  appearance    slim  cried  hi  red  and  waved  cheerfully  still  blinking  the  sleep  out  of  himself    red  kept  to  his  croaking  whisper  quiet  you  want  to  wake  somebody    slim  noticed  all  at  once  that  the  sun  scarcely  topped  the  low  hills  in  the  east  that  the  shadows  were  long  and  soft  and  that  the  grass  was  wet    slim  said  more  softly  whats  the  matter    red  only  waved  for  him  to  come  out    slim  dressed  quickly  gladly  confining  his  morning  wash  to  the  momentary  sprinkle  of  a  little  lukewarm  water  he  let  the  air  dry  the  exposed  portions  of  his  body  as  he  ran  out  while  bare  skin  grew  wet  against  the  dewy  grass    red  said  youve  got  to  be  quiet  if  mom  wakes  up  or  dad  or  your  dad  or  even  any  of  the  hands  then  itll  be  come  on  in  or  youll  catch  your  death  of  cold    he  mimicked  voice  and  tone  faithfully  so  that  slim  laughed  and  thought  that  there  had  never  been  so  funny  a  fellow  as  red    slim  said  eagerly  do  you  come  out  here  every  day  like  this  red  real  early  its  like  the  whole  world  is  just  yours  isnt  it  red  no  one  else  around  and  all  like  that  he  felt  proud  at  being  allowed  entrance  into  this  private  world    red  stared  at  him  sidelong  he  said  carelessly  ive  been  up  for  hours  didnt  you  hear  it  last  night    hear  what    thunder    was  there  a  thunderstorm  slim  never  slept  through  a  thunderstorm    i  guess  not  but  there  was  thunder  i  heard  it  and  then  i  went  to  the  window  and  it  wasnt  raining  it  was  all  stars  and  the  sky  was  just  getting  sort  of  almost  gray  you  know  what  i  mean    slim  had  never  seen  it  so  but  he  nodded    so  i  just  thought  id  go  out  said  red    they  walked  along  the  grassy  side  of  the  concrete  road  that  split  the  panorama  right  down  the  middle  all  the  way  down  to  where  it  vanished  among  the  hills  it  was  so  old  that  reds  father  couldnt  tell  red  when  it  had  been  built  it  didnt  have  a  crack  or  a  rough  spot  in  it    red  said  can  you  keep  a  secret    sure  red  what  kind  of  a  secret    just  a  secret  maybe  ill  tell  you  and  maybe  i  wont  i  dont  know  yet  red  broke  a  long  supple  stem  from  a  fern  they  passed  methodically  stripped  it  of  its  leaflets  and  swung  what  was  left  whipfashion  for  a  moment  he  was  on  a  wild  charger  which  reared  and  champed  under  his  iron  control  then  he  got  tired  tossed  the  whip  aside  and  stowed  the  charger  away  in  a  corner  of  his  imagination  for  future  use    he  sa ...

# %%
words = cleaned_string.split(' ')
words
# Out:
# ['youth',
#  '',
#  '',
#  '',
#  'by',
#  '',
#  'isaac',
#  '',
#  'asimov',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'red',
#  '',
#  'and',
#  '',
#  'slim',
#  '',
#  'found',
#  '',
#  'the',
#  '',
#  'two',
#  '',
#  'strange',
#  '',
#  'little',
#  '',
#  'animals',
#  '',
#  'the',
#  '',
#  'morning',
#  '',
#  'after',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'they',
#  '',
#  'heard',
#  '',
#  'the',
#  '',
#  'thunder',
#  '',
#  'sounds',
#  '',
#  'they',
#  '',
#  'knew',
#  '',
#  'that',
#  '',
#  'they',
#  '',
#  'could',
#  '',
#  'never',
#  '',
#  'show',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'their',
#  '',
#  'new',
#  '',
#  'pets',
#  '',
#  'to',
#  '',
#  'their',
#  '',
#  'parents',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'illustration',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'there',
#  '',
#  'was',
#  '',
#  'a',
#  '',
#  'spatter',
#  '',
#  'of',
#  '',
#  'pebbles',
#  '',
#  'against',
#  '',
#  'the',
#  '',
#  'window',
#  '',
#  'and',
#  '',
#  'the',
#  '',
#  'youngster',
#  '',
#  'stirred',
#  '',
#  'in',
#  '',
#  'his',
#  '',
#  'sleep',
#  '',
#  'another',
#  '',
#  'and',
#  '',
#  'he',
#  '',
#  'was',
#  '',
#  'awake',
#  '',
#  '',
#  '',
#  'he',
#  '',
#  'sat',
#  '',
#  'up',
#  '',
#  'stiffly',
#  '',
#  'in',
#  '',
#  'bed',
#  '',
#  'seconds',
#  '',
#  'passed',
#  '',
#  'while',
#  '',
#  'he',
#  '',
#  'interpreted',
#  '',
#  'his',
#  '',
#  'strange',
#  '',
#  'surroundings',
#  '',
#  'he',
#  '',
#  'wasnt',
#  '',
#  'in',
#  '',
#  'his',
#  '',
#  'own',
#  '',
#  'home',
#  '',
#  'of',
#  '',
#  'course',
#  '',
#  'this',
#  '',
#  'was',
#  '',
#  'out',
#  '',
#  'in',
#  '',
#  'the',
#  '',
#  'country',
#  '',
#  'it',
#  '',
#  'was',
#  '',
#  'colder',
#  '',
#  'than',
#  '',
#  'it',
#  '',
#  'should',
#  '',
#  'be',
#  '',
#  'and',
#  '',
#  'there',
#  '',
#  'was',
#  '',
#  'green',
#  '',
#  'at',
#  '',
#  'the',
#  '',
#  'window',
#  '',
#  '',
#  '',
#  'slim',
#  '',
#  '',
#  '',
#  'the',
#  '',
#  'call',
#  '',
#  'was',
#  '',
#  'a',
#  '',
#  'hoarse',
#  '',
#  'urgent',
#  '',
#  'whisper',
#  '',
#  'and',
#  '',
#  'the',
#  '',
#  'youngster',
#  '',
#  'bounded',
#  '',
#  'to',
#  '',
#  'the',
#  '',
#  'open',
#  '',
#  'window',
#  '',
#  '',
#  '',
#  'slim',
#  '',
#  'wasnt',
#  '',
#  'his',
#  '',
#  'real',
#  '',
#  'name',
#  '',
#  'but',
#  '',
#  'the',
#  '',
#  'new',
#  '',
#  'friend',
#  '',
#  'he',
#  '',
#  'had',
#  '',
#  'met',
#  '',
#  'the',
#  '',
#  'day',
#  '',
#  'before',
#  '',
#  'had',
#  '',
#  'needed',
#  '',
#  'only',
#  '',
#  'one',
#  '',
#  'look',
#  '',
#  'at',
#  '',
#  'his',
#  '',
#  'slight',
#  '',
#  'figure',
#  '',
#  'to',
#  '',
#  'say',
#  '',
#  'youre',
#  '',
#  'slim',
#  '',
#  'he',
#  '',
#  'added',
#  '',
#  'im',
#  '',
#  'red',
#  '',
#  '',
#  '',
#  'red',
#  '',
#  'wasnt',
#  '',
#  'his',
#  '',
#  'real',
#  '',
#  'name',
#  '',
#  'either',
#  '',
#  'but',
#  '',
#  'its',
#  '',
#  'appropriateness',
#  '',
#  'was',
#  '',
#  'obvious',
#  '',
#  'they',
#  '',
#  'were',
#  '',
#  'friends',
#  '',
#  'instantly',
#  '',
#  'with',
#  '',
#  'the',
#  '',
#  'quick',
#  '',
#  'unquestioning',
#  '',
#  'friendship',
#  '',
#  'of',
#  '',
#  'young',
#  '',
#  'ones',
#  '',
#  'not',
#  '',
#  'yet',
#  '',
#  'quite',
#  '',
#  'in',
#  '',
#  'adolescence',
#  '',
#  'before',
#  '',
#  'even',
#  '',
#  'the',
#  '',
#  'first',
#  '',
#  'stains',
#  '',
#  'of',
#  '',
#  'adulthood',
#  '',
#  'began',
#  '',
#  'to',
#  '',
#  'make',
#  '',
#  'their',
#  '',
#  'appearance',
#  '',
#  '',
#  '',
#  'slim',
#  '',
#  'cried',
#  '',
#  'hi',
#  '',
#  'red',
#  '',
#  'and',
#  '',
#  'waved',
#  '',
#  'cheerfully',
#  '',
#  'still',
#  '',
#  'blinking',
#  '',
#  'the',
#  '',
#  'sleep',
#  '',
#  'out',
#  '',
#  'of',
#  '',
#  'himself',
#  '',
#  '',
#  '',
#  'red',
#  '',
#  'kept',
#  '',
#  'to',
#  '',
#  'his',
#  '',
#  'croaking',
#  '',
#  'whisper',
#  '',
#  'quiet',
#  '',
#  'you',
#  '',
#  'want',
#  '',
#  'to',
#  '',
#  'wake',
#  '',
#  'somebody',
#  '',
#  '',
#  '',
#  'slim',
#  '',
#  'noticed',
#  '',
#  'all',
#  '',
#  'at',
#  '',
#  'once',
#  '',
#  'that',
#  '',
#  'the',
#  '',
#  'sun',
#  '',
#  'scarcely',
#  '',
#  'topped',
#  '',
#  'the',
#  '',
#  'low',
#  '',
#  'hills',
#  '',
#  'in',
#  '',
#  'the',
#  '',
#  'east',
#  '',
#  'that',
#  '',
#  'the',
#  '',
#  'shadows',
#  '',
#  'were',
#  '',
#  'long',
#  '',
#  'and',
#  '',
#  'soft',
#  '',
#  'and',
#  '',
#  'that',
#  '',
#  'the',
#  '',
#  'grass',
#  '',
#  'was',
#  '',
#  'wet',
#  '',
#  '',
#  '',
#  'slim',
#  '',
#  'said',
#  '',
#  'more',
#  '',
#  'softly',
#  '',
#  'whats',
#  '',
#  'the',
#  '',
#  'matter',
#  '',
#  '',
#  '',
#  'red',
#  '',
#  'only',
#  '',
#  'waved',
#  '',
#  'for',
#  '',
#  'him',
#  '',
#  'to',
#  '',
#  'come',
#  '',
#  'out',
#  '',
#  '',
#  '',
#  'slim',
#  '',
#  'dressed',
#  '',
#  'quickly',
#  '',
#  'gladly',
#  '',
#  'confining',
#  '',
#  'his',
#  '',
#  'morning',
#  '',
#  'wash',
#  '',
#  'to',
#  '',
#  'the',
#  '',
#  'momentary',
#  '',
#  'sprinkle',
#  '',
#  'of',
#  '',
#  'a',
#  '',
#  'little',
#  '',
#  'lukewarm',
#  '',
#  'water',
#  '',
#  'he',
#  '',
#  'let',
#  '',
#  'the',
#  '',
#  'air',
#  '',
#  'dry',
#  '',
#  'the',
#  '',
#  'exposed',
#  '',
#  'portions',
#  '',
#  'of',
#  '',
#  'his',
#  '',
#  'body',
#  '',
#  'as',
#  '',
#  'he',
#  '',
#  'ran',
#  '',
#  'out',
#  '',
#  'while',
#  '',
#  'bare',
#  '',
#  'skin',
#  '',
#  'grew',
#  '',
#  'wet',
#  '',
#  'against',
#  '',
#  'the',
#  '',
#  'dewy',
#  '',
#  'grass',
#  '',
#  '',
#  '',
#  'red',
#  '',
#  'said',
#  '',
#  'youve',
#  '',
#  'got',
#  '',
#  'to',
#  '',
#  'be',
#  '',
#  'quiet',
#  '',
#  'if',
#  '',
#  'mom',
#  '',
#  'wakes',
#  '',
#  'up',
#  '',
#  'or',
#  '',
#  'dad',
#  '',
#  'or',
#  '',
#  'your',
#  '',
#  'dad',
#  '',
#  'or',
#  '',
#  'even',
#  '',
#  'any',
#  '',
#  'of',
#  '',
#  'the',
#  '',
#  'hands',
#  '',
#  'then',
#  '',
#  'itll',
#  '',
#  'be',
#  '',
#  'come',
#  '',
#  'on',
#  '',
#  'in',
#  '',
#  'or',
#  '',
#  'youll',
#  '',
#  'catch',
#  '',
#  'your',
#  '',
#  'death',
#  '',
#  'of',
#  '',
#  'cold',
#  '',
#  '',
#  '',
#  'he',
#  '',
#  'mimicked',
#  '',
#  'voice',
#  '',
#  'and',
#  '',
#  'tone',
#  '',
#  'faithfully',
#  '',
#  'so',
#  '',
#  'that',
#  '',
#  'slim',
#  '',
#  'laughed',
#  '',
#  'and',
#  '',
#  'thought',
#  '',
#  'that',
#  '',
#  'there',
#  '',
#  'had',
#  '',
#  'never',
#  '',
#  'been',
#  '',
#  'so',
#  '',
#  'funny',
#  '',
#  'a',
#  '',
#  'fellow',
#  '',
#  'as',
#  '',
#  'red',
#  '',
#  '',
#  '',
#  'slim',
#  '',
#  'said',
#  '',
#  'eagerly',
#  '',
#  'do',
#  '',
#  'you',
#  '',
#  'come',
#  '',
#  'out',
#  '',
#  'here',
#  '',
#  'every',
#  '',
#  'day',
#  '',
#  'like',
#  '',
#  'this',
#  '',
#  'red',
#  '',
#  'real',
#  '',
#  'early',
#  '',
#  'its',
#  '',
#  'like',
#  '',
#  'the',
#  '',
#  'whole',
#  '',
#  'world',
#  '',
#  'is',
#  '',
#  'just',
#  '',
#  'yours',
#  '',
#  'isnt',
#  '',
#  'it',
#  '',
#  'red',
#  '',
#  'no',
#  '',
#  'one',
#  '',
#  'else',
#  '',
#  'around',
#  '',
#  'and',
#  '',
#  'all',
#  '',
#  'like',
#  '',
#  'that',
#  '',
#  'he',
#  '',
#  'felt',
#  '',
#  'proud',
#  '',
#  'at',
#  '',
#  'being',
#  '',
#  'allowed',
#  '',
#  'entrance',
#  '',
#  'into',
#  '',
#  'this',
#  '',
#  'private',
#  '',
#  'world',
#  '',
#  '',
#  '',
#  'red',
#  '',
#  'stared',
#  '',
#  'at',
#  '',
#  'him',
#  '',
#  'sidelong',
#  '',
#  'he',
#  '',
#  'said',
#  '',
#  'carelessly',
#  '',
#  'ive',
#  '',
#  'been',
#  '',
#  'up',
#  '',
#  'for',
#  '',
#  'hours',
#  '',
#  'didnt',
#  '',
#  'you',
#  '',
#  'hear',
#  '',
#  'it',
#  '',
#  'last',
#  '',
#  'night',
#  '',
#  '',
#  '',
#  'hear',
#  '',
#  'what',
#  '',
#  '',
#  '',
#  'thunder',
#  '',
#  '',
#  '',
#  'was',
#  '',
#  'there',
#  '',
#  'a',
#  '',
#  'thunderstorm',
#  '',
#  'slim',
#  '',
#  'never',
#  '',
#  'slept',
#  '',
#  'through',
#  '',
#  'a',
#  '',
#  'thunderstorm',
#  '',
#  '',
#  '',
#  'i',
#  '',
#  'guess',
#  '',
#  'not',
#  '',
#  'but',
#  '',
#  'there',
#  '',
#  'was',
#  '',
#  'thunder',
#  '',
#  'i',
#  '',
#  'heard',
#  '',
#  'it',
#  '',
#  'and',
#  '',
#  'then',
#  '',
#  'i',
#  '',
#  'went',
#  '',
#  'to',
#  '',
#  'the',
#  '',
#  'window',
#  '',
#  'and',
#  '',
#  'it',
#  '',
#  'wasnt',
#  '',
#  'raining',
#  '',
#  'it',
#  '',
#  'was',
#  '',
#  'all',
#  '',
#  'stars',
#  '',
#  'and',
#  '',
#  'the',
#  '',
#  'sky',
#  '',
#  'was',
#  '',
#  'just',
#  '',
#  ...]

# %%
word_count = {}

for word in words:
    if word != '':
        if word in word_count.keys():
            word_count[word] += 1
        else:
            word_count[word] = 1

word_count
# Out:
# {'really': 14,
#  'sounding': 2,
#  'it': 344,
#  'thought': 38,
#  'stopped': 4,
#  'safe': 4,
#  'stun': 2,
#  'stare': 2,
#  'weve': 6,
#  'quickly': 18,
#  'tell': 42,
#  'left': 10,
#  'secrecy': 4,
#  'face': 2,
#  'said': 240,
#  'eat': 24,
#  'exploration': 2,
#  'earnestly': 2,
#  'flooded': 2,
#  'forced': 2,
#  'damage': 2,
#  'tradition': 2,
#  'wants': 4,
#  'equivalent': 6,
#  'detective': 2,
#  'ejector': 2,
#  'our': 48,
#  'scoutship': 6,
#  'reverse': 2,
#  'vague': 2,
#  'presented': 2,
#  'impossible': 6,
#  'biting': 2,
#  'visible': 2,
#  'reds': 10,
#  'iron': 4,
#  'because': 28,
#  'east': 2,
#  'pilot': 8,
#  'unbelievable': 2,
#  'tubes': 2,
#  'properly': 2,
#  'know': 58,
#  'works': 2,
#  'whipfashion': 2,
#  'mathematical': 2,
#  'try': 10,
#  'you': 358,
#  'risen': 2,
#  'active': 2,
#  'species': 6,
#  'admirable': 2,
#  'by': 22,
#  'wife': 10,
#  'of': 368,
#  'color': 4,
#  'isaac': 2,
#  'masterly': 2,
#  'sleeping': 2,
#  'solvents': 2,
#  'cannot': 2,
#  'upset': 2,
#  'industrialists': 6,
#  'wateroxygen': 2,
#  'continent': 2,
#  'body': 6,
#  'trotted': 2,
#  'difficult': 2,
#  'victory': 2,
#  'lower': 2,
#  'why': 40,
#  'economy': 4,
#  'bearer': 2,
#  'theres': 16,
#  'rather': 8,
#  'myself': 4,
#  'place': 2,
#  'tame': 2,
#  'coal': 8,
#  'chopped': 10,
#  'sell': 2,
#  'room': 20,
#  'walking': 6,
#  'peeled': 2,
#  'didnt': 34,
#  'at': 124,
#  'afterwards': 2,
#  'doing': 6,
#  'rid': 10,
#  'sat': 2,
#  'something': 40,
#  'end': 8,
#  'gratis': 2,
#  'theory': 4,
#  'loft': 2,
#  'doors': 2,
#  'poorer': 4,
#  'occurrence': 2,
#  'worlds': 24,
#  'tried': 4,
#  'involves': 2,
#  'asleep': 2,
#  'spend': 4,
#  'especially': 2,
#  'asking': 4,
#  'movement': 2,
#  'seems': 4,
#  'coming': 8,
#  'remained': 8,
#  'visiplate': 4,
#  'precise': 2,
#  'eh': 6,
#  'possible': 2,
#  'panting': 2,
#  'my': 56,
#  'outnumbered': 2,
#  'flushed': 2,
#  'imminent': 2,
#  'youngsters': 12,
#  'yellow': 2,
#  'guess': 18,
#  'judge': 4,
#  'surein': 2,
#  'itll': 4,
#  'vi': 2,
#  'intelligent': 8,
#  'drown': 2,
#  'considerably': 2,
#  'appeared': 4,
#  'isnt': 26,
#  'receptor': 2,
#  'opportunity': 4,
#  'grind': 2,
#  'calculator': 2,
#  'attempt': 2,
#  'business': 6,
#  'proud': 4,
#  'voluble': 2,
#  'contains': 2,
#  'experience': 2,
#  'never': 22,
#  'past': 2,
#  'include': 2,
#  'permission': 2,
#  'rarely': 2,
#  'less': 10,
#  'covered': 2,
#  'awake': 6,
#  'arcturian': 4,
#  'check': 2,
#  'sudden': 4,
#  'project': 2,
#  'search': 4,
#  'whispered': 4,
#  'interested': 4,
#  'load': 2,
#  'galaxy': 6,
#  'noises': 4,
#  'power': 4,
#  'today': 2,
#  'ejectors': 2,
#  'gun': 2,
#  'thems': 2,
#  'away': 34,
#  'therell': 4,
#  'destruction': 2,
#  'momentum': 2,
#  'road': 6,
#  'ignorant': 2,
#  'cheerfully': 4,
#  'principle': 2,
#  'pull': 2,
#  'ate': 8,
#  'light': 2,
#  'disintegrator': 4,
#  'shallowly': 2,
#  'gall': 2,
#  'healthy': 2,
#  'civilization': 6,
#  'perturbed': 2,
#  'pardon': 6,
#  'landhungry': 2,
#  'twilight': 2,
#  'eaten': 2,
#  'wonder': 6,
#  'green': 4,
#  'killing': 2,
#  'menu': 4,
#  'certain': 2,
#  'acting': 4,
#  'written': 2,
#  'maam': 2,
#  '3': 2,
#  'are': 120,
#  'saying': 10,
#  'surroundings': 2,
#  'solar': 10,
#  'rocket': 4,
#  'simpler': 2,
#  'xi': 2,
#  'shes': 4,
#  'concrete': 2,
#  'strange': 14,
#  'mastered': 2,
#  'trade': 12,
#  'muttered': 6,
#  'glibly': 2,
#  'detail': 2,
#  'cook': 14,
#  'name': 10,
#  'tidings': 2,
#  'throbbing': 2,
#  'appearance': 4,
#  'fruit': 4,
#  'rise': 2,
#  'conceive': 2,
#  'clock': 2,
#  'bar': 2,
#  'theyve': 16,
#  'your': 60,
#  'company': 2,
#  'sounded': 6,
#  'making': 10,
#  'dark': 2,
#  'sense': 6,
#  'dont': 90,
#  'peace': 2,
#  'main': 6,
#  'found': 22,
#  'further': 2,
#  'fiercely': 2,
#  'move': 4,
#  'freighter': 2,
#  'feed': 8,
#  'diameter': 2,
#  'parents': 2,
#  'fresh': 2,
#  'thickly': 2,
#  'care': 14,
#  'agony': 2,
#  'annoyed': 2,
#  'hadnt': 4,
#  'crowds': 2,
#  'magazine': 2,
#  'dipped': 2,
#  'important': 8,
#  'sounds': 2,
#  'attack': 4,
#  'grass': 18,
#  'frowning': 2,
#  'hole': 6,
#  'thoughtprojector': 2,
#  'joined': 2,
#  'exposed': 2,
#  'agreed': 4,
#  'blaster': 2,
#  'set': 2,
#  'tears': 2,
#  'astronomers': 8,
#  'impressed': 2,
#  'rings': 2,
#  'momentary': 2,
#  'leaving': 2,
#  'methodically': 2,
#  'caught': 8,
#  'earlier': 2,
#  'trick': 2,
#  'known': 2,
#  'maybe': 14,
#  'water': 6,
#  'government': 2,
#  'recovered': 4,
#  'monstrosity': 2,
#  'nodded': 6,
#  'before': 40,
#  'yet': 14,
#  'tawdry': 2,
#  'passed': 4,
#  'from': 68,
#  'nasty': 2,
#  'worth': 2,
#  'monopoly': 2,
#  'speculation': 4,
#  'thank': 4,
#  'terms': 4,
#  'rodents': 2,
#  'reflection': 2,
#  'children': 4,
#  'worried': 2,
#  'crab': 2,
#  'redi': 2,
#  'rescue': 2,
#  'definite': 2,
#  'prepare': 2,
#  'wondered': 2,
#  'almost': 20,
#  'best': 6,
#  'probed': 2,
#  'instantly': 2,
#  'colder': 2,
#  'placatingly': 2,
#  'touched': 4,
#  'understand': 8,
#  'out': 78,
#  'thrusting': 2,
#  'havent': 8,
#  'objects': 2,
#  'shuddered': 2,
#  'existed': 2,
#  'proceed': 2,
#  'hide': 2,
#  'what': 116,
#  'people': 10,
#  'pressure': 4,
#  'turned': 24,
#  'realized': 4,
#  'over': 24,
#  'picked': 2,
#  'job': 6,
#  'argumentative': 4,
#  'except': 10,
#  'miserably': 2,
#  'lacked': 2,
#  'youngster': 14,
#  'upward': 2,
#  'heard': 16,
#  'least': 10,
#  'accident': 2,
#  'describe': 8,
#  'explain': 2,
#  'different': 8,
#  'afterward': 2,
#  'direction': 8,
#  'glories': 2,
#  'howd': 4,
#  'drop': 2,
#  '1': 2,
#  'handle': 2,
#  'distant': 2,
#  'changing': 2,
#  'lose': 2,
#  'behind': 8,
#  'retreat': 2,
#  'swung': 6,
#  'followed': 6,
#  'sonormal': 2,
#  'pay': 2,
#  'its': 84,
#  'idea': 6,
#  'big': 6,
#  'meat': 38,
#  'somewhat': 2,
#  'ends': 2,
#  'wait': 6,
#  'pharmaceuticals': 2,
#  'effort': 2,
#  'vow': 2,
#  'speak': 20,
#  'us': 32,
#  'falling': 2,
#  'whats': 20,
#  'till': 6,
#  'hydrogen': 12,
#  'meal': 2,
#  'system': 10,
#  'therefore': 2,
#  'eventually': 2,
#  'wordsyoull': 2,
#  'piercing': 2,
#  'guns': 2,
#  'focussing': 2,
#  'burial': 2,
#  'contact': 2,
#  'taken': 8,
#  'fine': 2,
#  'discussion': 2,
#  'crack': 2,
#  'got': 50,
#  'golly': 4,
#  'black': 6,
#  'live': 6,
#  'complain': 2,
#  'skin': 4,
#  'foolishness': 2,
#  'cover': 4,
#  'talking': 12,
#  'boredom': 2,
#  'vii': 2,
#  'control': 6,
#  'biggest': 6,
#  'height': 4,
#  'surely': 4,
#  'happens': 2,
#  'racial': 2,
#  'disbelieve': 2,
#  'since': 6,
#  'drew': 4,
#  'repulsive': 2,
#  'sprained': 2,
#  'affected': 2,
#  'citybred': 2,
#  'bitterly': 2,
#  'periods': 2,
#  'richer': 4,
#  'everywhere': 2,
#  'bloodpoison': 2,
#  'unique': 6,
#  'good': 26,
#  'kind': 6,
#  'mom': 4,
#  'iv': 2,
#  'throw': 2,
#  'aided': 2,
#  'comfortable': 2,
#  'stung': 2,
#  'grimaced': 4,
#  'no': 104,
#  'suspect': 2,
#  'deal': 2,
#  'interstellar': 4,
#  'valid': 2,
#  'profits': 2,
#  'tracks': 2,
#  'dewy': 2,
#  'leaflets': 2,
#  'whirled': 2,
#  'fool': 4,
#  'giant': 4,
#  'stared': 6,
#  'sighed': 4,
#  'paid': 2,
#  'silly': 2,
#  'peoplethings': 2,
#  'implying': 2,
#  'hysteria': 2,
#  'jogs': 2,
#  'called': 4,
#  'entire': 2,
#  'doesnt': 2,
#  'monster': 6,
#  'ridiculous': 2,
#  'greeted': 2,
#  'companion': 2,
#  'reminded': 2,
#  'smile': 2,
#  'following': 2,
#  'intervened': 2,
#  'sir': 40,
#  'tortures': 2,
#  'fell': 2,
#  'moved': 8,
#  'merchant': 38,
#  'waiting': 2,
#  'thing': 18,
#  'briars': 2,
#  'spiral': 2,
#  'watch': 6,
#  'horriblelooking': 2,
#  'apologize': 2,
#  'war': 2,
#  'screeched': 2,
#  'little': 30,
#  'unsettling': 2,
#  'look': 30,
#  'solvent': 8,
#  'gently': 4,
#  'advance': 2,
#  'imagination': 2,
#  'feats': 2,
#  'handful': 2,
#  'this': 72,
#  'feeling': 2,
#  'inspired': 2,
#  'rich': 4,
#  'process': 2,
#  'breaths': 2,
#  'same': 6,
#  'punishment': 4,
#  'miserable': 2,
#  'crash': 4,
#  'teaches': 2,
#  'lad': 8,
#  'up': 50,
#  'hurried': 2,
#  'nearer': 2,
#  'bowl': 2,
#  'agreement': 2,
#  'brightened': 2,
#  'thoughts': 6,
#  'alone': 4,
#  'through': 10,
#  'ground': 10,
#  'enunciation': 2,
#  'sidelong': 2,
#  'during': 4,
#  'months': 2,
#  'such': 22,
#  'items': 4,
#  'father': 34,
#  'looked': 52,
#  'truth': 2,
#  'promised': 4,
#  'conversation': 2,
#  'hi': 4,
#  'approach': 2,
#  'interpret': 2,
#  'five': 2,
#  'stairs': 4,
#  'adolescence': 2,
#  'organize': 2,
#  'being': 12,
#  'huskily': 2,
#  'distances': 2,
#  'force': 2,
#  'demanded': 2,
#  'sleeps': 2,
#  'despite': 6,
#  'surrounded': 2,
#  'looking': 12,
#  'faced': 2,
#  'full': 2,
#  'cool': 2,
#  'energetically': 2,
#  'islandsi': 2,
#  'cage': 22,
#  'planetary': 8,
#  'must': 4,
#  'after': 24,
#  'pendulumfashion': 2,
#  'missed': 2,
#  'received': 4,
#  'smelling': 2,
#  'concentration': 2,
#  'apparently': 2,
#  'change': 14,
#  'stroke': 2,
#  'base': 2,
#  'substitute': 2,
#  'mile': 2,
#  'supposed': 2,
#  'defend': 2,
#  'unaware': 2,
#  'potential': 8,
#  'week': 2,
#  'looks': 4,
#  'filled': 2,
#  'an': 56,
#  'coincidences': 2,
#  'caves': 2,
#  'breathe': 2,
#  'aback': 2,
#  'occur': 4,
#  'done': 16,
#  'truthful': 4,
#  'imperiously': 2,
#  'pain': 2,
#  'meant': 12,
#  'early': 6,
#  'feet': 4,
#  'carried': 2,
#  'those': 18,
#  'but': 102,
#  'lightseconds': 2,
#  'changes': 2,
#  'hedge': 2,
#  'alive': 4,
#  'argument': 6,
#  'realize': 2,
#  'ours': 10,
#  'sauntered': 2,
#  'northern': 2,
#  'significant': 2,
#  'personal': 2,
#  'troubles': 2,
#  'groups': 2,
#  'cellophane': 2,
#  'and': 478,
#  'circumstances': 2,
#  'age': 6,
#  'hurt': 14,
#  'soupy': 2,
#  'bald': 2,
#  'atomic': 16,
#  'whopping': 2,
#  'rolled': 2,
#  'bombs': 4,
#  'using': 2,
#  'breathing': 2,
#  'gentleness': 4,
#  'native': 14,
#  'directed': 2,
#  'rough': 4,
#  'dry': 2,
#  'direct': 2,
#  'lukewarm': 2,
#  'fellow': 6,
#  'decided': 2,
#  'attention': 4,
#  'point': 14,
#  'going': 34,
#  'enough': 16,
#  'exploring': 4,
#  'cooks': 6,
#  'worry': 8,
#  'seizing': 2,
#  'comers': 2,
#  'absorption': 2,
#  'slims': 2,
#  'join': 4,
#  'significance': 2,
#  'take': 26,
#  'intense': 2,
#  'be': 134,
#  'common': 2,
#  'creatures': 18,
#  'sheer': 2,
#  'indignantly': 2,
#  'noticed': 6,
#  'beneath': 2,
#  'capture': 4,
#  'peaceful': 4,
#  'canvas': 14,
#  'crystals': 2,
#  'dangerous': 2,
#  'frozen': 2,
#  'vanishing': 2,
#  'seen': 8,
#  'interesting': 2,
#  'earth': 4,
#  'anything': 28,
#  'stop': 2,
#  'answer': 8,
#  'projector': 6,
#  'briskly': 2,
#  'charred': 2,
#  'appear': 2,
#  'split': 2,
#  'technology': 4,
#  'grasp': 2,
#  'wet': 4,
#  'introversion': 2,
#  'superdense': 8,
#  'real': 14,
#  'most': 8,
#  'send': 2,
#  'death': 4,
#  'eyes': 14,
#  'underbrush': 2,
#  'stuck': 2,
#  'else': 8,
#  'chance': 12,
#  'lay': 2,
#  'guest': 8,
#  'atom': 2,
#  'object': 4,
#  'unsupported': 2,
#  'distance': 6,
#  'game': 2,
#  'ingredients': 2,
#  'maintained': 2,
#  'slope': 2,
#  'tentacles': 4,
#  'handweapons': 2,
#  'than': 26,
#  'reconnaissance': 2,
#  'stalks': 6,
#  'getting': 10,
#  'middle': 2,
#  'merchants': 2,
#  'nerves': 2,
#  'crew': 2,
#  'heavy': 2,
#  'destroy': 2,
#  'treated': 4,
#  'strap': 2,
#  'certainly': 4,
#  'x': 2,
#  'trouble': 2,
#  'fashion': 2,
#  'decadence': 2,
#  'acrobats': 4,
#  'glamorous': 2,
#  'uncharacteristically': 2,
#  'anythingll': 2,
#  'circuses': 2,
#  'hurts': 2,
#  'vessel': 2,
#  'resist': 2,
#  'run': 4,
#  'trailed': 2,
#  'range': 4,
#  'path': 2,
#  'trees': 6,
#  'hug': 2,
#  'few': 10,
#  'proved': 2,
#  'post': 2,
#  'weak': 2,
#  'speaking': 2,
#  'class': 4,
#  'easily': 2,
#  'ever': 14,
#  'travel': 6,
#  'chemistry': 4,
#  'quite': 22,
#  'very': 20,
#  'planets': 30,
#  'horrible': 4,
#  'industry': 2,
#  'just': 60,
#  'so': 50,
#  'down': 16,
#  'stealing': 2,
#  'fault': 10,
#  'bare': 2,
#  'supple': 2,
#  'entered': 6,
#  'controls': 4,
#  'discussing': 2,
#  'awakened': 4,
#  'own': 20,
#  'march': 2,
#  'lost': 16,
#  'hear': 12,
#  'closer': 6,
#  'professor': 2,
#  'excited': 2,
#  'stellar': 8,
#  'slowly': 6,
#  'not': 148,
#  'figure': 6,
#  'acted': 2,
#  'scoot': 2,
#  'flourishing': 2,
#  'xiii': 2,
#  'selfreliant': 2,
#  'density': 2,
#  'swaying': 2,
#  'needed': 4,
#  'as': 74,
#  'volumes': 2,
#  'survived': 6,
#  'indignant': 2,
#  'question': 4,
#  'identity': 2,
#  'clean': 2,
#  'quiet': 6,
#  'grievances': 2,
#  'strong': 2,
#  'figures': 2,
#  'effect': 2,
#  'ropy': 2,
#  'women': 2,
#  'beforethewars': 14,
#  'assume': 2,
#  'wooden': 2,
#  'means': 2,
#  'wild': 2,
#  'apart': 2,
#  'pitch': 2,
#  'revolting': 2,
#  'shake': 2,
#  'price': 4,
#  'galaxyand': 2,
#  'imponderable': 2,
#  'there': 104,
#  'panic': 2,
#  'student': 2,
#  'fern': 2,
#  'gesturing': 2,
#  'playing': 2,
#  'bite': 2,
#  'differences': 4,
#  'casual': 2,
#  'trip': 4,
#  'men': 2,
#  'use': 10,
#  'consider': 4,
#  'fought': 2,
#  'madly': 2,
#  'artillery': 2,
#  'reversal': 2,
#  'fodder': 2,
#  'peering': 2,
#  'theyre': 34,
#  'cried': 4,
#  'similar': 4,
#  'raw': 8,
#  'lowered': 2,
#  'far': 4,
#  'urgent': 2,
#  'invasion': 2,
#  'stepped': 6,
#  'become': 2,
#  'seven': 2,
#  'penalty': 2,
#  'safely': 2,
#  'animals': 60,
#  'ancient': 2,
#  'offered': 2,
#  'berries': 4,
#  'met': 2,
#  'descending': 4,
#  'softly': 4,
#  'reached': 8,
#  'home': 4,
#  'useful': 2,
#  'purpose': 2,
#  'asimov': 2,
#  'headed': 2,
#  'barn': 22,
#  'finds': 2,
#  'goes': 2,
#  'ten': 4,
#  'old': 16,
#  'consequences': 4,
#  'reason': 10,
#  'burn': 2,
#  'family': 2,
#  'panorama': 2,
#  'then': 58,
#  'advanced': 2,
#  'telepathery': 2,
#  'toothpicks': 2,
#  'grew': 4,
#  'practically': 2,
#  'open': 10,
#  'well': 58,
#  'dismiss': 2,
#  'unusual': 4,
#  'want': 32,
#  'do': 82,
#  'blank': 2,
#  'sky': 6,
#  'wheres': 2,
#  'rigidly': 2,
#  'quietly': 2,
#  'unexpected': 2,
#  'tired': 8,
#  'xiv': 2,
#  'shouldnt': 4,
#  'comes': 8,
#  'fly': 2,
#  'fixed': 2,
#  'times': 2,
#  'how': 30,
#  'answering': 4,
#  'wood': 2,
#  'someday': 2,
#  'rent': 2,
#  'spot': 2,
#  'knows': 4,
#  'knowledge': 4,
#  'quarreling': 2,
#  'leaping': 2,
#  'them': 174,
#  'maintaining': 2,
#  'noble': 2,
#  'hello': 4,
#  'large': 10,
#  'believed': 2,
#  'independently': 2,
#  'calm': 2,
#  'microscopic': 2,
#  'under': 8,
#  'inhabitants': 2,
#  'immediate': 2,
#  'laughed': 2,
#  'overcalculation': 2,
#  'atmosphere': 6,
#  'obviously': 6,
#  'doublework': 2,
#  'hungry': 2,
#  'unquestioning': 2,
#  'soon': 2,
#  'investigated': 2,
#  'steady': 2,
#  'punished': 2,
#  'crazy': 6,
#  'living': 4,
#  'caged': 2,
#  'completely': 4,
#  'grotesquely': 2,
#  'hope': 6,
#  'pour': 2,
#  'younguns': 2,
#  'rest': 2,
#  'easy': 4,
#  'bodies': 2,
#  'leave': 4,
#  'brood': 2,
#  'overcome': 2,
#  'possession': 2,
#  'uneconomical': 2,
#  'does': 2,
#  'morning': 8,
#  'only': 60,
#  'top': 2,
#  'cautious': 2,
#  'makes': 4,
#  'faltered': 2,
#  'competition': 2,
#  'easilyrecognized': 2,
#  'development': 4,
#  'fleet': 2,
#  'glad': 4,
#  'clamped': 2,
#  'possibly': 4,
#  'werent': 6,
#  'owned': 2,
#  'ones': 8,
#  'chose': 2,
#  'zillions': 2,
#  'benefit': 4,
#  'plastics': 2,
#  'law': 2,
#  'entering': 2,
#  'hills': 4,
#  'formed': 4,
#  'deep': 2,
#  'efforts': 2,
#  'otherwisewell': 2,
#  'thunder': 10,
#  'fact': 8,
#  'scarcely': 2,
#  'daring': 2,
#  'been': 54,
#  'me': 76,
#  'private': 4,
#  'about': 66,
#  'theirs': 6,
#  'burnt': 4,
#  'sleep': 8,
#  'install': 2,
#  'smaller': 10,
#  'a': 342,
#  'toward': 22,
#  'wouldnt': 20,
#  'themselves': 6,
#  'bury': 2,
#  'gave': 4,
#  'wall': 2,
#  'true': 8,
#  'theyll': 12,
#  'suitable': 2,
#  'came': 22,
#  'university': 4,
#  'quavered': 4,
#  'one': 58,
#  'resentfully': 2,
#  'peevishly': 2,
#  'if': 92,
#  'or': 58,
#  'harm': 16,
#  'their': 78,
#  'suggest': 2,
#  'ashes': 2,
#  'long': 16,
#  'extrapolated': 2,
#  'hydrogenammonia': 4,
#  'barely': 2,
#  'methane': 2,
#  'hesitantly': 2,
#  'noise': 4,
#  'favorably': 2,
#  'combustion': 2,
#  'seconds': 2,
#  'iii': 2,
#  'actual': 2,
#  'seem': 2,
#  'turn': 4,
#  'struggled': 4,
#  'asteroids': 2,
#  'went': 12,
#  'always': 8,
#  'rules': 2,
#  'statements': 2,
#  'youre': 24,
#  'doubt': 6,
#  'xii': 2,
#  'wash': 2,
#  'slight': 2,
#  'back': 30,
#  'fools': 4,
#  'inside': 6,
#  'disturbing': 2,
#  'chivvy': 2,
#  'spaceworthiness': 2,
#  'youth': 22,
#  'another': 14,
#  'either': 2,
#  'everyone': 2,
#  'much': 22,
#  'scrambled': 2,
#  'which': 50,
#  'wail': 2,
#  'destroyed': 2,
#  'walked': 6,
#  'soils': 2,
#  'listen': 6,
#  ...}

# %%
import pandas as pd

words = []
count = []

for key, value in word_count.items():
    words.append(key)
    count.append(value)

df = pd.DataFrame({'word': words, 'count': count})

# %%
df
# Out:
#       count          word
# 0        14        really
# 1         2      sounding
# 2       344            it
# 3        38       thought
# 4         4       stopped
# 5         4          safe
# 6         2          stun
# 7         2         stare
# 8         6          weve
# 9        18       quickly
# 10       42          tell
# 11       10          left
# 12        4       secrecy
# 13        2          face
# 14      240          said
# 15       24           eat
# 16        2   exploration
# 17        2     earnestly
# 18        2       flooded
# 19        2        forced
# 20        2        damage
# 21        2     tradition
# 22        4         wants
# 23        6    equivalent
# 24        2     detective
# 25        2       ejector
# 26       48           our
# 27        6     scoutship
# 28        2       reverse
# 29        2         vague
# ...     ...           ...
# 1892      2          edge
# 1893     12        window
# 1894      2      millions
# 1895      8         sorry
# 1896      8       nothing
# 1897      2       parties
# 1898      4        devise
# 1899      2   oxygenwater
# 1900      2        forces
# 1901      4          acts
# 1902      2       decorum
# 1903      2  thisthiscage
# 1904      8     astronomy
# 1905      6          need
# 1906      2        phrase
# 1907      2       revived
# 1908      2    suspicious
# 1909      2      stations
# 1910      2        lowest
# 1911      6         blast
# 1912      4     hesitated
# 1913      2   targetpoint
# 1914      2         above
# 1915      6      visitors
# 1916      2       nearest
# 1917      2    yetperhaps
# 1918      2      vanished
# 1919      4         plain
# 1920      2        rimmed
# 1921      4      repaired
#
# [1922 rows x 2 columns]
